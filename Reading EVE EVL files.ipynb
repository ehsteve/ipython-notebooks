# %%
file = '/Users/schriste/Downloads/EVL_L2_2014079_10_004_01.fit.gz'

# %%
from astropy.io import fits as pyfits

# %%
fits = pyfits.open(file)

# %%
fits[0].header
# Out:
# SIMPLE  =                    T /Dummy Created by MWRFITS v1.11
# BITPIX  =                    8 /Dummy primary header created by MWRFITS
# NAXIS   =                    0 /No data is associated with this header
# EXTEND  =                    T /Extensions may (will!) be present

# %%
fits[1].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                   39 /Number of bytes per row
# NAXIS2  =                   30 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    7 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# EXTNAME = 'LinesMeta'
# TUNIT1  = 'nm'
# TUNIT2  = 'nm'
# TUNIT3  = 'nm'
# TUNIT4  = 'log(K)'
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'WAVE_CENTER'        /
# TTYPE2  = 'WAVE_MIN'           /
# TTYPE3  = 'WAVE_MAX'           /
# TTYPE4  = 'LOGT    '           /
# TTYPE5  = 'NAME    '           /
# TTYPE6  = 'TYPE    '           /
# TTYPE7  = 'BLENDS  '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = 'E       '           /
# ...

# %%
fits[1].data
# Out:
# FITS_rec([(9.3926001, 9.3299999, 9.4300003, 6.8099999, 'Fe XVIII', 'F', ''),
#        (13.124, 13.04, 13.17, 5.5700002, 'Fe VIII', 'K', 'Fe VIII'),
#        (13.285, 13.23, 13.32, 6.9699998, 'Fe XX', 'N', 'Fe XXIII'),
#        (17.107, 17.02, 17.24, 5.8099999, 'Fe IX', 'Ar', ''),
#        (17.7243, 17.629999, 17.83, 5.9899998, 'Fe X', 'Cl', 'Fe VII'),
#        (18.040701, 17.959999, 18.15, 6.0700002, 'Fe XI', 'S', 'Fe X, Fe VII'),
#        (19.511999, 19.43, 19.610001, 6.1300001, 'Fe XII', 'P', ''),
#        (20.204399, 20.139999, 20.32, 6.1900001, 'Fe XIII', 'Si', 'Fe XI, Fe XII'),
#        (21.133101, 21.07, 21.200001, 6.27, 'Fe XIV', 'Al', 'Fe XII'),
#        (25.631701, 25.549999, 25.68, 4.75, 'He II', 'H', ''),
#        (28.415001, 28.299999, 28.5, 6.3000002, 'Fe XV', 'Mg', ''),
#        (30.3783, 30.25, 30.5, 4.6999998, 'He II', 'H', ''),
#        (33.541, 33.470001, 33.610001, 6.4299998, 'Fe XVI', 'Na', ''),
# ...

# %%
fits[2].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                   17 /Number of bytes per row
# NAXIS2  =                   20 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    2 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# EXTNAME = 'BandsMeta'
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'NAME    '           /
# TTYPE2  = 'TYPE    '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '13A     '           /
# TFORM2  = '4A      '           /
# COMMENT  For every element in the BAND_* column in the LinesData table, there is
# COMMENT  one row here describing the band.
# COMMENT  name is the name of the band
# ...

# %%
fits[2].data
# Out:
# FITS_rec([('AIA_A94', 'AIA'), ('AIA_A131', 'AIA'), ('AIA_A171', 'AIA'),
#        ('AIA_A193', 'AIA'), ('AIA_A211', 'AIA'), ('AIA_A304', 'AIA'),
#        ('AIA_A335', 'AIA'), ('GOES-14 EUV-A', 'GOES'),
#        ('GOES-14 EUV-B', 'GOES'), ('MA171', 'ESP'), ('MA257', 'ESP'),
#        ('MA304', 'ESP'), ('MA366', 'ESP'), ('E7-37', 'MEGS'),
#        ('E37-45', 'MEGS'), ('MEGS-A1', 'MEGS'), ('MEGS-A2', 'MEGS'),
#        ('MEGS-B short', 'MEGS'), ('MEGS-B both', 'MEGS'),
#        ('MEGS-B long', 'MEGS')],
#       dtype=[('NAME', 'S13'), ('TYPE', 'S4')])

# %%
fits[4].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                    5 /Number of bytes per row
# NAXIS2  =                    4 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    2 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# EXTNAME = 'QuadMeta'
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'NAME    '           /
# TTYPE2  = 'TYPE    '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '2A      '           /
# TFORM2  = '3A      '           /
# COMMENT  For every element in the QUAD_* column in the LinesData table, there is
# COMMENT  one row here describing the quadrant.
# COMMENT  name is the name of the quadrant
# ...

# %%
fits[4].data
# Out:
# FITS_rec([('Q0', 'ESP'), ('Q1', 'ESP'), ('Q2', 'ESP'), ('Q3', 'ESP')],
#       dtype=[('NAME', 'S2'), ('TYPE', 'S3')])

# %%
fits[5].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                  782 /Number of bytes per row
# NAXIS2  =                  360 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                   19 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# TFORM11 = '20E     '           /
# TFORM12 = '6E      '           /
# TFORM13 = '6E      '           /
# TFORM14 = '6E      '           /
# TFORM15 = '6E      '           /
# TFORM16 = '4E      '           /
# TFORM17 = '4E      '           /
# TFORM18 = '4E      '           /
# TFORM19 = '4E      '           /
# TTYPE11 = 'BAND_ACCURACY'      /
# TTYPE12 = 'DIODE_IRRADIANCE'   /
# TTYPE13 = 'DIODE_STDEV'        /
# TTYPE14 = 'DIODE_PRECISION'    /
# ...

# %%
fits[5].data
# Out:
# FITS_rec([ (1774000848.3478274, 2014079, 36013.34782743454, 2, 0, array([  9.33472620e-06,   3.66915401e-06,   1.41044757e-06,
#          6.82599348e-05,   5.12137740e-05,   7.64124270e-05,
#          6.31853400e-05,   5.73253492e-05,   4.55600057e-05,
#          4.79096561e-05,   9.95895825e-05,   5.80196967e-04,
#          6.27813497e-05,  -1.00000000e+00,   4.88229125e-05,
#         -1.00000000e+00,  -1.00000000e+00,  -1.00000000e+00,
#         -1.00000000e+00,  -1.00000000e+00,  -1.00000000e+00,
#         -1.00000000e+00,  -1.00000000e+00,  -1.00000000e+00,
#         -1.00000000e+00,  -1.00000000e+00,  -1.00000000e+00,
#         -1.00000000e+00,  -1.00000000e+00,  -1.00000000e+00], dtype=float32), array([ 0.04977621,  0.07340711,  0.11975553,  0.03740922,  0.03128497,
#         0.02631183,  0.03090025,  0.03440683,  0.04259199,  0.06365069,
#         0.05594869,  0.04192809,  0.11719117, -1.        ,  0.18109977,
# ...

# %%
fits[5].columns
# Out:
# ColDefs(
#     name = 'TAI'; format = 'D'
#     name = 'YYYYDOY'; format = 'J'
#     name = 'SOD'; format = 'D'
#     name = 'FLAGS'; format = 'B'
#     name = 'SC_FLAGS'; format = 'B'
#     name = 'LINE_IRRADIANCE'; format = '30E'; unit = 'W m^-2'
#     name = 'LINE_PRECISION'; format = '30E'
#     name = 'LINE_ACCURACY'; format = '30E'
#     name = 'BAND_IRRADIANCE'; format = '20E'
#     name = 'BAND_PRECISION'; format = '20E'
#     name = 'BAND_ACCURACY'; format = '20E'
#     name = 'DIODE_IRRADIANCE'; format = '6E'; unit = 'W m^-2'
#     name = 'DIODE_STDEV'; format = '6E'
#     name = 'DIODE_PRECISION'; format = '6E'
#     name = 'DIODE_ACCURACY'; format = '6E'
#     name = 'QUAD_FRACTION'; format = '4E'
#     name = 'QUAD_STDEV'; format = '4E'
#     name = 'QUAD_PRECISION'; format = '4E'
#     name = 'QUAD_ACCURACY'; format = '4E'
# )

# %%
fits[5].data['TAI']
# Out:
# array([  1.77400085e+09,   1.77400086e+09,   1.77400087e+09,
#          1.77400088e+09,   1.77400089e+09,   1.77400090e+09,
#          1.77400091e+09,   1.77400092e+09,   1.77400093e+09,
#          1.77400094e+09,   1.77400095e+09,   1.77400096e+09,
#          1.77400097e+09,   1.77400098e+09,   1.77400099e+09,
#          1.77400100e+09,   1.77400101e+09,   1.77400102e+09,
#          1.77400103e+09,   1.77400104e+09,   1.77400105e+09,
#          1.77400106e+09,   1.77400107e+09,   1.77400108e+09,
#          1.77400109e+09,   1.77400110e+09,   1.77400111e+09,
#          1.77400112e+09,   1.77400113e+09,   1.77400114e+09,
#          1.77400115e+09,   1.77400116e+09,   1.77400117e+09,
#          1.77400118e+09,   1.77400119e+09,   1.77400120e+09,
#          1.77400121e+09,   1.77400122e+09,   1.77400123e+09,
#          1.77400124e+09,   1.77400125e+09,   1.77400126e+09,
#          1.77400127e+09,   1.77400128e+09,   1.77400129e+09,
# ...

# %%
fits[5].data['TAI'].shape
# Out:
# (360,)

# %%
fits[5].data['LINE_IRRADIANCE'].shape
# Out:
# (360, 30)
