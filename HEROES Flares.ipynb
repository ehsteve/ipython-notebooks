# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_dir = '/Users/schriste/Desktop/HEROES_flares'

# %%
import glob

# %%
filelist = glob.glob(data_dir + '/ssw_cutout_20130921_19*AIA_94_.fts')

# %%
filelist
# Out:
# ['/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190002_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190014_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190026_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190038_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190050_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190102_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190114_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190126_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190138_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190150_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190202_AIA_94_.fts',
#  '/Users/schriste/Desktop/HEROES_flares/ssw_cutout_20130921_190214_AIA_94_.fts',
# ...

# %%
import sunpy.map

# %%
cubemap = sunpy.map.Map(filelist, cube=True)

# %%
cubemap.peek()
